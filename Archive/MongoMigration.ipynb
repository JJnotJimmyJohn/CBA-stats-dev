# %%
import os

# %%
os.getcwd()
# Out:
# '/Documents/CBA_Stats/Scraping'

# %%
os.chdir('..')

# %%
os.getcwd()
# Out:
# '/Documents/CBA_Stats'

# %%
from cbastats import Scraper
import pymongo
from dotenv import load_dotenv

# %% [markdown]
# # Get the Original Data

# %%
sina_scraper = Scraper.SinaScraper(Scraper.SINA_SCHEDULE_BASE_URL, Scraper.ENCODING, Scraper.PARSER, Scraper.HEADERS)

# %%
schedule = sina_scraper.query_schedule()
schedule
# Out:
#        轮次                  日期  主队       比分  客队  战报  统计  组图  地点 电视  ...  \
# 0     第1轮 2019-11-01 19:35:00  广东   107:98  辽宁  战报  统计  组图  东莞     ...
# 1     第1轮 2019-11-02 19:35:00  江苏    96:97  浙江  战报  统计  组图  苏州     ...
# 2     第1轮 2019-11-02 19:35:00  四川   87:134  新疆  战报  统计  组图  成都     ...
# 3     第1轮 2019-11-02 19:35:00  山东   108:95  八一  战报  统计  组图  济南     ...
# 4     第1轮 2019-11-02 19:35:00  北控  108:103  深圳  战报  统计  组图  北京     ...
# ..    ...                 ...  ..      ...  ..  ..  ..  ..  .. ..  ...
# 619  第17轮 2020-12-11 11:00:00  广州   94:111  山东  战报  统计  组图  诸暨     ...
# 620  第17轮 2020-12-11 12:30:00  辽宁  122:108  北控  战报  统计  组图  诸暨     ...
# 621  第17轮 2020-12-11 15:30:00  青岛   116:95  同曦  战报  统计  组图  诸暨     ...
# 622  第17轮 2020-12-11 19:35:00  江苏  110:106  天津  战报  统计  组图  诸暨     ...
# 623  第17轮 2020-12-11 20:00:00  吉林    90:97  新疆  战报  统计  组图  诸暨     ...
#
#                                                比分_link  \
# 0    http://cba.sports.sina.com.cn/cba/schedule/sho...
# ...

# %%
schedule.to_dict('records')
# Out:
# [{'轮次': '第1轮',
#   '日期': Timestamp('2019-11-01 19:35:00'),
#   '主队': '广东',
#   '比分': '107:98',
#   '客队': '辽宁',
#   '战报': '战报',
#   '统计': '统计',
#   '组图': '组图',
#   '地点': '东莞',
#   '电视': '',
#   '轮次_link': '',
#   '日期_link': '',
#   '主队_link': 'http://cba.sports.sina.com.cn/cba/team/show/1/',
#   '比分_link': 'http://cba.sports.sina.com.cn/cba/schedule/show/18381/',
#   '客队_link': 'http://cba.sports.sina.com.cn/cba/team/show/9/',
#   '战报_link': 'http://sports.sina.com.cn/basketball/cba/2019-11-01/doc-iicezzrr6602072.shtml',
#   '统计_link': 'http://cba.sports.sina.com.cn/cba/schedule/show/18381/',
#   '组图_link': 'http://slide.sports.sina.com.cn/cba/slide_2_792_233270.html',
#   '地点_link': '',
#   '电视_link': '',
#   'SinaGame_ID': '18381',
#   '客队ID': '9',
#   '主队ID': '1'},
#  {'轮次': '第1轮',
#   '日期': Timestamp('2019-11-02 19:35:00'),
#   '主队': '江苏',
#   '比分': '96:97',
#   '客队': '浙江',
#   '战报': '战报',
#   '统计': '统计',
#   '组图': '组图',
#   '地点': '苏州',
#   '电视': '',
#   '轮次_link': '',
# ...

# %%
plays = sina_scraper.run_query_db('SELECT * FROM CBA_Data.Playbyplay')
plays
# Out:
#        eventid teamid shotcoordx shotcoordy eventtypeid quarternum minutes  \
# 0                   0          0          0          19          4       0
# 1                   0          0          0          15          4       0
# 2               29129    14.9722      15.54           4          4       0
# 3               29124     3.3272      -0.78           3          4       0
# 4               29129    -1.5123      21.78           4          4       0
# ...        ...    ...        ...        ...         ...        ...     ...
# 166468          29129          1          1           1          1      11
# 166469          29124          0          0           8          1      11
# 166470          29129     1.8958     1.4575           3          1      11
# 166471          29124          0          0          12          1      12
# 166472              0          0          0          14          1      12
#
# ...

# %%
PlayerStatsPerGame = sina_scraper.run_query_db('SELECT * FROM CBA_Data.PlayerStatsPerGame')
PlayerStatsPerGame
# Out:
#                                                  球员_link    球员  号码  出场时间  首发  \
# 0      http://cba.sports.sina.com.cn/cba/player/show/...  布鲁克斯   6    36   1
# 1      http://cba.sports.sina.com.cn/cba/player/show/...   任骏飞  20    30   1
# 2       http://cba.sports.sina.com.cn/cba/player/show/3/   易建联   9    35   1
# 3      http://cba.sports.sina.com.cn/cba/player/show/...    赵睿  10    31   1
# 4      http://cba.sports.sina.com.cn/cba/player/show/...   胡明轩   3    13   1
# ...                                                  ...   ...  ..   ...  ..
# 21880  http://cba.sports.sina.com.cn/cba/player/show/...   冶征文  18     0   0
# 21881  http://cba.sports.sina.com.cn/cba/player/show/...   吴永盛  10     0   0
# 21882  http://cba.sports.sina.com.cn/cba/player/show/...   梁英淇  12     0   0
# 21883  http://cba.sports.sina.com.cn/cba/player/show/...  鲁吐布拉  14     0   0
# 21884  http://cba.sports.sina.com.cn/cba/player/show/...   王小乙   1     0   0
#
# ...

# %% [markdown]
# # Create database and collections(tables) in MongoDB

# %%
mongodb_pwd = os.getenv('MONGODB_PWD')
mongodb_username = os.getenv('MONGODB_USERNAME')

# %%
# connect to the cluster
client = pymongo.MongoClient(f"mongodb+srv://{mongodb_username}:{mongodb_pwd}@cbastats.wllis.mongodb.net/")

# %%
client.list_database_names()
# Out:
# ['testdb', 'admin', 'local']

# %% [markdown]
# ### Production DB

# %%
# connect to a database
# will create if the database does not exist
db = client["cbaStatsDB"]

# %%
db.list_collection_names()
# Out:
# ['gameSchedule']

# %%
db.gameSchedule.insert_many(schedule.to_dict('records'))

# %%
db.gamePlays.insert_many(plays.to_dict('records'))

# %%
db.playerStatsPerGame.insert_many(PlayerStatsPerGame.to_dict('records'))

# %%
db.stagingGameSchedule.insert_many(schedulele.to_dict('records'))

# %%
db.stagingGamePlays.insert_many(plays.to_dict('records'))

# %%
db.stagingPlayerStatsPerGame.insert_many(PlayerStatsPerGame.to_dict('records'))

# %%
client.close()

# %% [markdown]
# ### Test DB

# %%
# connect to a database
# will create if the database does not exist
db = client["testCbaStatsDB"]

# %%
db.list_collection_names()
# Out:
# []

# %%
db.gameSchedule.insert_many(schedule.to_dict('records'))

# %%
db.gamePlays.insert_many(plays.to_dict('records'))

# %%
db.playerStatsPerGame.insert_many(PlayerStatsPerGame.to_dict('records'))

# %%
db.stagingGameSchedule.insert_many(schedule.to_dict('records'))

# %%
db.stagingGamePlays.insert_many(plays.to_dict('records'))

# %%
db.stagingPlayerStatsPerGame.insert_many(PlayerStatsPerGame.to_dict('records'))

# %%
client.close()

# %%
# db.Collection.find({ /* criteria */}).limit(1).size();
