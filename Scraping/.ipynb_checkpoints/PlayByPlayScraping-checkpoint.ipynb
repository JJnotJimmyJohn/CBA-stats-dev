# %%
import requests
from bs4 import BeautifulSoup
# import lxml.html as lh
from bs4 import BeautifulSoup
import pandas as pd
import datetime
import numpy as np
import re
import time
import json

from bokeh.plotting import figure, output_notebook, show

from bokeh.palettes import Reds6,Blues8

# %%
Reds6
# Out:
# ['#a50f15', '#de2d26', '#fb6a4a', '#fc9272', '#fcbba1', '#fee5d9']

# %% [markdown]
# # Schedule

# %%
def get_schedule_page(round_num,leagueID=401,
                 url=r"http://sportsdata.misports.cn/beitai/cba/schedule/getschedulelist",
                headers={"User-Agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.119 Safari/537.36"},
                encoding='utf-8'):
    if round_num >46:
        raise ValueError('CBA共有46轮，请输入小于等于46的数字。')
        return
    if round_num < 0:
        raise ValueError('起始轮必须大于等于0')
        return
    # Get this round's page
    data = {"round": round_num,"leagueID": leagueID}
    r = requests.post(url, data=data, headers=headers)
    if r.status_code != 200:
        print('网页数据返回异常。')
        return
    r.encoding=encoding
    soup = BeautifulSoup(r.content, "html.parser")
    return soup, round_num

# %%
def get_games_from_page(soup,round_num):
    current_round_games=[]
    current_round = {}
    current_round['轮次'] = str(round_num)
    # 一个section在网页上对应一个比赛日
    for section in soup.find_all('div',attrs={"class":"section2"}):
        titles = [span.text.strip() for span in section.find('div', attrs={"class":'title'}).find_all('span')]
        games = []
        # 每一行是一场比赛
        for row in section.find('table').find_all('tr'):
            games.append([td.text.strip()+'|'+td.find('a')['href'] if td.find('a') else td.text.strip() for td in row.find_all('td')])
        for game in games:
            if '未开始' in game:
                # exit function
                pass
        for game in games:
            game_dict = {}
            game_dict['比赛日'] = re.sub('\s','',section.find('div',attrs={'class':'time1'}).text)
            for title,data_item in zip(titles,game):
                game_dict[title]=data_item
            current_round_games.append(game_dict)
    
    current_round['本轮比赛'] = current_round_games
    return current_round

# %% [markdown]
# # Game Plays

# %%
def get_plays(scheduleid,leagueid,
                    headers={
                        "User-Agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.119 Safari/537.36"
                    },
                   url = r"http://sportsdata.misports.cn/beitai/cba/live/liveeventdetails",
                   encoding='UTF-8'):
    data = {"scheduleid": scheduleid,"leagueid": leagueid}
    r = requests.post(url, data=data, headers=headers,)
    r.encoding=encoding
    soup = BeautifulSoup(r.content, "html.parser")
    all_events = []
    for event in soup.find_all("li"):
        event_dic = event.attrs
        li = list(event.find_all('span'))
        if li:
            event_dic['event']=li[2].text
            event_dic['score']=li[3].text
            all_events.append(event_dic)
            
    return all_events

# %% [markdown]
# # Scraping

# %%
all_rounds = []
start_round=1
end_round=29
for round_num in range(start_round,end_round+1):
    soup, _ = get_schedule_page(round_num)
    current_round = get_games_from_page(soup,round_num)
    all_rounds.append(current_round)

# %%
all_plays=[]
for one_round in all_rounds:
    round_num = one_round['轮次']
    games_this_round = one_round['本轮比赛']
    for game in games_this_round:
        game_date = game['比赛日']
        home_tm = {game['主队'][-5:]:game['主队'].split('|')[0]}
        away_tm = {game['客队'][-5:]:game['客队'].split('|')[0]}
        if game['状态'] =='未开始':
            print(f'Round {round_num}, {game_date}, {home_tm} vs. {away_tm} 未开始，跳过')
            continue
        leagueid = game['比分'].split('&')[0][-3:]
        scheduleid = game['比分'].split('&')[1][-9:]
        print(f'Scraping round {round_num}, {game_date}, {home_tm} vs. {away_tm}, {scheduleid}')
        # game['plays'] = get_events(scheduleid,leagueid)
        all_plays.extend(get_events(scheduleid,leagueid))
        time.sleep(np.random.rand()*3)
        print('-----------------------------')
print('Complete!')
# Out:
# Scraping round 1, 11月01日,周五, {'29124': '广东东莞银行'} vs. {'29129': '辽宁本钢'}, 100025839
# -----------------------------
# Scraping round 1, 11月02日,周六, {'29118': '苏州肯帝亚'} vs. {'29140': '浙江稠州银行'}, 100025840
# -----------------------------
# Scraping round 1, 11月02日,周六, {'29127': '四川五粮金樽'} vs. {'29117': '新疆伊力特'}, 100025841
# -----------------------------
# Scraping round 1, 11月02日,周六, {'29130': '山东西王'} vs. {'29116': '八一南昌'}, 100025849
# -----------------------------
# Scraping round 1, 11月02日,周六, {'29136': '北京控股'} vs. {'29131': '深圳马可波罗'}, 100025851
# -----------------------------
# Scraping round 1, 11月02日,周六, {'29125': '上海久事'} vs. {'29133': '南京同曦宙光'}, 100025855
# -----------------------------
# Scraping round 1, 11月02日,周六, {'29135': '青岛国信双星'} vs. {'29137': '九台农商银行'}, 100025857
# -----------------------------
# Scraping round 1, 11月02日,周六, {'29128': '浙江广厦控股'} vs. {'29134': '福建豹发力'}, 100025859
# -----------------------------
# Scraping round 1, 11月03日,周日, {'29138': '天津先行者'} vs. {'29115': '北京首钢'}, 100025861
# -----------------------------
# Scraping round 1, 11月03日,周日, {'29139': '时代中国广州'} vs. {'29132': '山西汾酒股份'}, 100025865
# -----------------------------
# Scraping round 2, 11月04日,周一, {'29129': '辽宁本钢'} vs. {'29128': '浙江广厦控股'}, 100025867
# -----------------------------
# Scraping round 2, 11月05日,周二, {'29136': '北京控股'} vs. {'29125': '上海久事'}, 100025871
# -----------------------------
# Scraping round 2, 11月05日,周二, {'29133': '南京同曦宙光'} vs. {'29118': '苏州肯帝亚'}, 100025873
# -----------------------------
# Scraping round 2, 11月05日,周二, {'29132': '山西汾酒股份'} vs. {'29134': '福建豹发力'}, 100025876
# -----------------------------
# Scraping round 2, 11月05日,周二, {'29135': '青岛国信双星'} vs. {'29116': '八一南昌'}, 100025878
# -----------------------------
# Scraping round 2, 11月05日,周二, {'29117': '新疆伊力特'} vs. {'29140': '浙江稠州银行'}, 100025880
# -----------------------------
# Scraping round 2, 11月05日,周二, {'29124': '广东东莞银行'} vs. {'29127': '四川五粮金樽'}, 100025881
# -----------------------------
# Scraping round 2, 11月06日,周三, {'29115': '北京首钢'} vs. {'29130': '山东西王'}, 100025885
# -----------------------------
# Scraping round 2, 11月06日,周三, {'29138': '天津先行者'} vs. {'29137': '九台农商银行'}, 100025887
# -----------------------------
# Scraping round 2, 11月06日,周三, {'29131': '深圳马可波罗'} vs. {'29139': '时代中国广州'}, 100025891
# -----------------------------
# Scraping round 3, 11月07日,周四, {'29133': '南京同曦宙光'} vs. {'29127': '四川五粮金樽'}, 100025912
# -----------------------------
# Scraping round 3, 11月07日,周四, {'29134': '福建豹发力'} vs. {'29135': '青岛国信双星'}, 100025920
# -----------------------------
# Scraping round 3, 11月07日,周四, {'29117': '新疆伊力特'} vs. {'29128': '浙江广厦控股'}, 100025923
# -----------------------------
# Scraping round 3, 11月08日,周五, {'29118': '苏州肯帝亚'} vs. {'29138': '天津先行者'}, 100025932
# -----------------------------
# Scraping round 3, 11月08日,周五, {'29139': '时代中国广州'} vs. {'29136': '北京控股'}, 100025936
# -----------------------------
# Scraping round 3, 11月08日,周五, {'29115': '北京首钢'} vs. {'29125': '上海久事'}, 100025942
# -----------------------------
# Scraping round 3, 11月08日,周五, {'29129': '辽宁本钢'} vs. {'29131': '深圳马可波罗'}, 100025944
# -----------------------------
# Scraping round 3, 11月08日,周五, {'29137': '九台农商银行'} vs. {'29116': '八一南昌'}, 100025947
# -----------------------------
# Scraping round 3, 11月08日,周五, {'29124': '广东东莞银行'} vs. {'29130': '山东西王'}, 100025949
# -----------------------------
# Scraping round 3, 01月09日,周四, {'29140': '浙江稠州银行'} vs. {'29132': '山西汾酒股份'}, 100025927
# -----------------------------
# Scraping round 4, 11月09日,周六, {'29133': '南京同曦宙光'} vs. {'29140': '浙江稠州银行'}, 100025952
# -----------------------------
# Scraping round 4, 11月10日,周日, {'29128': '浙江广厦控股'} vs. {'29132': '山西汾酒股份'}, 100025956
# -----------------------------
# Scraping round 4, 11月10日,周日, {'29134': '福建豹发力'} vs. {'29117': '新疆伊力特'}, 100025958
# -----------------------------
# Scraping round 4, 11月10日,周日, {'29118': '苏州肯帝亚'} vs. {'29127': '四川五粮金樽'}, 100025960
# -----------------------------
# Scraping round 4, 11月10日,周日, {'29130': '山东西王'} vs. {'29139': '时代中国广州'}, 100025963
# -----------------------------
# Scraping round 4, 11月10日,周日, {'29125': '上海久事'} vs. {'29138': '天津先行者'}, 100025964
# -----------------------------
# Scraping round 4, 11月10日,周日, {'29115': '北京首钢'} vs. {'29135': '青岛国信双星'}, 100025968
# -----------------------------
# Scraping round 4, 11月10日,周日, {'29131': '深圳马可波罗'} vs. {'29136': '北京控股'}, 100025971
# -----------------------------
# Scraping round 4, 11月10日,周日, {'29129': '辽宁本钢'} vs. {'29116': '八一南昌'}, 100025974
# -----------------------------
# Scraping round 4, 11月10日,周日, {'29137': '九台农商银行'} vs. {'29124': '广东东莞银行'}, 100025977
# -----------------------------
# Scraping round 5, 11月12日,周二, {'29130': '山东西王'} vs. {'29138': '天津先行者'}, 100025984
# -----------------------------
# Scraping round 5, 11月12日,周二, {'29129': '辽宁本钢'} vs. {'29133': '南京同曦宙光'}, 100025986
# -----------------------------
# Scraping round 5, 11月12日,周二, {'29132': '山西汾酒股份'} vs. {'29125': '上海久事'}, 100025989
# -----------------------------
# Scraping round 5, 11月12日,周二, {'29135': '青岛国信双星'} vs. {'29139': '时代中国广州'}, 100025991
# -----------------------------
# Scraping round 5, 11月13日,周三, {'29131': '深圳马可波罗'} vs. {'29115': '北京首钢'}, 100025995
# -----------------------------
# Scraping round 5, 11月13日,周三, {'29128': '浙江广厦控股'} vs. {'29118': '苏州肯帝亚'}, 100025997
# -----------------------------
# Scraping round 5, 11月13日,周三, {'29116': '八一南昌'} vs. {'29134': '福建豹发力'}, 100025999
# -----------------------------
# Scraping round 5, 11月13日,周三, {'29117': '新疆伊力特'} vs. {'29137': '九台农商银行'}, 100026003
# -----------------------------
# Scraping round 5, 11月14日,周四, {'29127': '四川五粮金樽'} vs. {'29124': '广东东莞银行'}, 100026005
# -----------------------------
# Scraping round 5, 11月14日,周四, {'29136': '北京控股'} vs. {'29140': '浙江稠州银行'}, 100026007
# -----------------------------
# Scraping round 6, 11月15日,周五, {'29118': '苏州肯帝亚'} vs. {'29115': '北京首钢'}, 100026018
# -----------------------------
# Scraping round 6, 11月15日,周五, {'29117': '新疆伊力特'} vs. {'29129': '辽宁本钢'}, 100026023
# -----------------------------
# Scraping round 6, 11月16日,周六, {'29132': '山西汾酒股份'} vs. {'29133': '南京同曦宙光'}, 100026030
# -----------------------------
# Scraping round 6, 11月16日,周六, {'29127': '四川五粮金樽'} vs. {'29139': '时代中国广州'}, 100026034
# -----------------------------
# Scraping round 6, 11月16日,周六, {'29138': '天津先行者'} vs. {'29140': '浙江稠州银行'}, 100026037
# -----------------------------
# Scraping round 6, 11月16日,周六, {'29135': '青岛国信双星'} vs. {'29134': '福建豹发力'}, 100026040
# -----------------------------
# Scraping round 6, 11月16日,周六, {'29130': '山东西王'} vs. {'29124': '广东东莞银行'}, 100026043
# -----------------------------
# Scraping round 6, 11月17日,周日, {'29136': '北京控股'} vs. {'29128': '浙江广厦控股'}, 100026049
# -----------------------------
# Scraping round 6, 11月17日,周日, {'29131': '深圳马可波罗'} vs. {'29125': '上海久事'}, 100026052
# -----------------------------
# Scraping round 6, 11月17日,周日, {'29116': '八一南昌'} vs. {'29137': '九台农商银行'}, 100026056
# -----------------------------
# Scraping round 7, 11月19日,周二, {'29138': '天津先行者'} vs. {'29127': '四川五粮金樽'}, 100026061
# -----------------------------
# Scraping round 7, 11月19日,周二, {'29125': '上海久事'} vs. {'29118': '苏州肯帝亚'}, 100026063
# -----------------------------
# Scraping round 7, 11月19日,周二, {'29133': '南京同曦宙光'} vs. {'29128': '浙江广厦控股'}, 100026067
# -----------------------------
# Scraping round 7, 11月19日,周二, {'29140': '浙江稠州银行'} vs. {'29129': '辽宁本钢'}, 100026074
# -----------------------------
# Scraping round 7, 11月19日,周二, {'29135': '青岛国信双星'} vs. {'29130': '山东西王'}, 100026078
# -----------------------------
# Scraping round 7, 11月19日,周二, {'29134': '福建豹发力'} vs. {'29116': '八一南昌'}, 100026081
# -----------------------------
# Scraping round 7, 11月19日,周二, {'29124': '广东东莞银行'} vs. {'29117': '新疆伊力特'}, 100026084
# -----------------------------
# Scraping round 7, 11月20日,周三, {'29139': '时代中国广州'} vs. {'29131': '深圳马可波罗'}, 100026089
# -----------------------------
# Scraping round 7, 11月20日,周三, {'29115': '北京首钢'} vs. {'29136': '北京控股'}, 100026093
# -----------------------------
# Scraping round 7, 11月20日,周三, {'29132': '山西汾酒股份'} vs. {'29137': '九台农商银行'}, 100026097
# -----------------------------
# Scraping round 8, 11月21日,周四, {'29118': '苏州肯帝亚'} vs. {'29135': '青岛国信双星'}, 100026103
# -----------------------------
# Scraping round 8, 11月21日,周四, {'29130': '山东西王'} vs. {'29127': '四川五粮金樽'}, 100026106
# -----------------------------
# Scraping round 8, 11月21日,周四, {'29125': '上海久事'} vs. {'29128': '浙江广厦控股'}, 100026108
# -----------------------------
# Scraping round 8, 11月21日,周四, {'29140': '浙江稠州银行'} vs. {'29134': '福建豹发力'}, 100026113
# -----------------------------
# Scraping round 8, 11月21日,周四, {'29138': '天津先行者'} vs. {'29124': '广东东莞银行'}, 100026117
# -----------------------------
# Scraping round 8, 11月22日,周五, {'29139': '时代中国广州'} vs. {'29117': '新疆伊力特'}, 100026121
# -----------------------------
# Scraping round 8, 11月22日,周五, {'29131': '深圳马可波罗'} vs. {'29116': '八一南昌'}, 100026123
# -----------------------------
# Scraping round 8, 11月22日,周五, {'29133': '南京同曦宙光'} vs. {'29132': '山西汾酒股份'}, 100026125
# -----------------------------
# Scraping round 8, 11月22日,周五, {'29129': '辽宁本钢'} vs. {'29115': '北京首钢'}, 100026128
# -----------------------------
# Scraping round 8, 11月22日,周五, {'29137': '九台农商银行'} vs. {'29136': '北京控股'}, 100026130
# -----------------------------
# Scraping round 9, 11月23日,周六, {'29118': '苏州肯帝亚'} vs. {'29130': '山东西王'}, 100026135
# -----------------------------
# Scraping round 9, 11月23日,周六, {'29128': '浙江广厦控股'} vs. {'29140': '浙江稠州银行'}, 100026139
# -----------------------------
# Scraping round 9, 11月23日,周六, {'29135': '青岛国信双星'} vs. {'29127': '四川五粮金樽'}, 100026142
# -----------------------------
# Scraping round 9, 11月24日,周日, {'29116': '八一南昌'} vs. {'29138': '天津先行者'}, 100026145
# -----------------------------
# Scraping round 9, 11月24日,周日, {'29139': '时代中国广州'} vs. {'29125': '上海久事'}, 100026147
# -----------------------------
# Scraping round 9, 11月24日,周日, {'29131': '深圳马可波罗'} vs. {'29117': '新疆伊力特'}, 100026149
# -----------------------------
# Scraping round 9, 11月24日,周日, {'29132': '山西汾酒股份'} vs. {'29124': '广东东莞银行'}, 100026151
# -----------------------------
# Scraping round 9, 11月24日,周日, {'29129': '辽宁本钢'} vs. {'29136': '北京控股'}, 100026154
# -----------------------------
# Scraping round 9, 11月24日,周日, {'29137': '九台农商银行'} vs. {'29115': '北京首钢'}, 100026156
# -----------------------------
# Scraping round 9, 11月24日,周日, {'29134': '福建豹发力'} vs. {'29133': '南京同曦宙光'}, 100026158
# -----------------------------
# Scraping round 10, 11月26日,周二, {'29136': '北京控股'} vs. {'29115': '北京首钢'}, 100026162
# -----------------------------
# Scraping round 10, 11月26日,周二, {'29139': '时代中国广州'} vs. {'29138': '天津先行者'}, 100026165
# -----------------------------
# Scraping round 10, 11月26日,周二, {'29125': '上海久事'} vs. {'29131': '深圳马可波罗'}, 100026167
# -----------------------------
# Scraping round 10, 11月26日,周二, {'29133': '南京同曦宙光'} vs. {'29124': '广东东莞银行'}, 100026172
# -----------------------------
# Scraping round 10, 11月26日,周二, {'29140': '浙江稠州银行'} vs. {'29130': '山东西王'}, 100026174
# -----------------------------
# Scraping round 10, 11月26日,周二, {'29128': '浙江广厦控股'} vs. {'29135': '青岛国信双星'}, 100026177
# -----------------------------
# Scraping round 10, 11月26日,周二, {'29117': '新疆伊力特'} vs. {'29116': '八一南昌'}, 100026180
# -----------------------------
# Scraping round 10, 11月27日,周三, {'29127': '四川五粮金樽'} vs. {'29137': '九台农商银行'}, 100026183
# -----------------------------
# Scraping round 10, 11月27日,周三, {'29132': '山西汾酒股份'} vs. {'29129': '辽宁本钢'}, 100026185
# -----------------------------
# Scraping round 10, 11月27日,周三, {'29134': '福建豹发力'} vs. {'29118': '苏州肯帝亚'}, 100026187
# -----------------------------
# Scraping round 11, 11月28日,周四, {'29125': '上海久事'} vs. {'29139': '时代中国广州'}, 100025842
# -----------------------------
# Scraping round 11, 11月28日,周四, {'29115': '北京首钢'} vs. {'29116': '八一南昌'}, 100025844
# -----------------------------
# Scraping round 11, 11月28日,周四, {'29133': '南京同曦宙光'} vs. {'29131': '深圳马可波罗'}, 100025845
# -----------------------------
# Scraping round 11, 11月28日,周四, {'29140': '浙江稠州银行'} vs. {'29135': '青岛国信双星'}, 100025847
# -----------------------------
# Scraping round 11, 11月28日,周四, {'29128': '浙江广厦控股'} vs. {'29130': '山东西王'}, 100025848
# -----------------------------
# Scraping round 11, 11月29日,周五, {'29117': '新疆伊力特'} vs. {'29136': '北京控股'}, 100025961
# -----------------------------
# Scraping round 11, 11月29日,周五, {'29118': '苏州肯帝亚'} vs. {'29137': '九台农商银行'}, 100025854
# -----------------------------
# Scraping round 11, 11月29日,周五, {'29127': '四川五粮金樽'} vs. {'29129': '辽宁本钢'}, 100025856
# -----------------------------
# Scraping round 11, 11月29日,周五, {'29138': '天津先行者'} vs. {'29132': '山西汾酒股份'}, 100025858
# -----------------------------
# Scraping round 11, 11月29日,周五, {'29124': '广东东莞银行'} vs. {'29134': '福建豹发力'}, 100025954
# -----------------------------
# Scraping round 12, 11月30日,周六, {'29130': '山东西王'} vs. {'29125': '上海久事'}, 100025862
# -----------------------------
# Scraping round 12, 11月30日,周六, {'29131': '深圳马可波罗'} vs. {'29128': '浙江广厦控股'}, 100025864
# -----------------------------
# Scraping round 12, 11月30日,周六, {'29116': '八一南昌'} vs. {'29139': '时代中国广州'}, 100025866
# -----------------------------
# Scraping round 12, 11月30日,周六, {'29135': '青岛国信双星'} vs. {'29133': '南京同曦宙光'}, 100025869
# -----------------------------
# Scraping round 12, 12月01日,周日, {'29118': '苏州肯帝亚'} vs. {'29132': '山西汾酒股份'}, 100025872
# -----------------------------
# Scraping round 12, 12月01日,周日, {'29127': '四川五粮金樽'} vs. {'29136': '北京控股'}, 100025874
# -----------------------------
# Scraping round 12, 12月01日,周日, {'29115': '北京首钢'} vs. {'29124': '广东东莞银行'}, 100025875
# -----------------------------
# Scraping round 12, 12月01日,周日, {'29140': '浙江稠州银行'} vs. {'29137': '九台农商银行'}, 100025877
# -----------------------------
# Scraping round 12, 12月01日,周日, {'29129': '辽宁本钢'} vs. {'29138': '天津先行者'}, 100025879
# -----------------------------
# Scraping round 12, 12月01日,周日, {'29117': '新疆伊力特'} vs. {'29134': '福建豹发力'}, 100025882
# -----------------------------
# Scraping round 13, 12月03日,周二, {'29139': '时代中国广州'} vs. {'29115': '北京首钢'}, 100025888
# -----------------------------
# Scraping round 13, 12月03日,周二, {'29130': '山东西王'} vs. {'29133': '南京同曦宙光'}, 100025889
# -----------------------------
# Scraping round 13, 12月04日,周三, {'29132': '山西汾酒股份'} vs. {'29128': '浙江广厦控股'}, 100025892
# -----------------------------
# Scraping round 13, 12月04日,周三, {'29140': '浙江稠州银行'} vs. {'29129': '辽宁本钢'}, 100025893
# -----------------------------
# Scraping round 13, 12月04日,周三, {'29138': '天津先行者'} vs. {'29136': '北京控股'}, 100025896
# -----------------------------
# Scraping round 13, 12月04日,周三, {'29118': '苏州肯帝亚'} vs. {'29117': '新疆伊力特'}, 100025897
# -----------------------------
# Scraping round 13, 12月04日,周三, {'29125': '上海久事'} vs. {'29135': '青岛国信双星'}, 100025899
# -----------------------------
# Scraping round 13, 12月04日,周三, {'29137': '九台农商银行'} vs. {'29134': '福建豹发力'}, 100025901
# -----------------------------
# Scraping round 13, 12月05日,周四, {'29131': '深圳马可波罗'} vs. {'29127': '四川五粮金樽'}, 100025903
# -----------------------------
# Scraping round 13, 12月05日,周四, {'29116': '八一南昌'} vs. {'29124': '广东东莞银行'}, 100025904
# -----------------------------
# Scraping round 14, 12月06日,周五, {'29136': '北京控股'} vs. {'29130': '山东西王'}, 100025907
# -----------------------------
# Scraping round 14, 12月06日,周五, {'29133': '南京同曦宙光'} vs. {'29140': '浙江稠州银行'}, 100025909
# -----------------------------
# Scraping round 14, 12月06日,周五, {'29128': '浙江广厦控股'} vs. {'29138': '天津先行者'}, 100025911
# -----------------------------
# Scraping round 14, 12月06日,周五, {'29134': '福建豹发力'} vs. {'29125': '上海久事'}, 100025916
# -----------------------------
# Scraping round 14, 12月07日,周六, {'29132': '山西汾酒股份'} vs. {'29127': '四川五粮金樽'}, 100025919
# -----------------------------
# Scraping round 14, 12月07日,周六, {'29135': '青岛国信双星'} vs. {'29124': '广东东莞银行'}, 100025924
# -----------------------------
# Scraping round 14, 12月07日,周六, {'29139': '时代中国广州'} vs. {'29129': '辽宁本钢'}, 100025926
# -----------------------------
# Scraping round 14, 12月08日,周日, {'29115': '北京首钢'} vs. {'29131': '深圳马可波罗'}, 100025931
# -----------------------------
# Scraping round 14, 12月08日,周日, {'29116': '八一南昌'} vs. {'29118': '苏州肯帝亚'}, 100025934
# -----------------------------
# Scraping round 14, 12月08日,周日, {'29137': '九台农商银行'} vs. {'29117': '新疆伊力特'}, 100025935
# -----------------------------
# Scraping round 15, 12月09日,周一, {'29134': '福建豹发力'} vs. {'29136': '北京控股'}, 100025939
# -----------------------------
# Scraping round 15, 12月10日,周二, {'29115': '北京首钢'} vs. {'29139': '时代中国广州'}, 100025941
# -----------------------------
# Scraping round 15, 12月10日,周二, {'29140': '浙江稠州银行'} vs. {'29116': '八一南昌'}, 100025943
# -----------------------------
# Scraping round 15, 12月10日,周二, {'29129': '辽宁本钢'} vs. {'29133': '南京同曦宙光'}, 100025945
# -----------------------------
# Scraping round 15, 12月10日,周二, {'29137': '九台农商银行'} vs. {'29125': '上海久事'}, 100025965
# -----------------------------
# Scraping round 15, 12月10日,周二, {'29124': '广东东莞银行'} vs. {'29128': '浙江广厦控股'}, 100025967
# -----------------------------
# Scraping round 15, 12月10日,周二, {'29130': '山东西王'} vs. {'29118': '苏州肯帝亚'}, 100025970
# -----------------------------
# Scraping round 15, 12月10日,周二, {'29132': '山西汾酒股份'} vs. {'29117': '新疆伊力特'}, 100025973
# -----------------------------
# Scraping round 15, 12月10日,周二, {'29135': '青岛国信双星'} vs. {'29131': '深圳马可波罗'}, 100025975
# -----------------------------
# Scraping round 15, 12月11日,周三, {'29127': '四川五粮金樽'} vs. {'29138': '天津先行者'}, 100025978
# -----------------------------
# Scraping round 16, 12月12日,周四, {'29136': '北京控股'} vs. {'29139': '时代中国广州'}, 100025980
# -----------------------------
# Scraping round 16, 12月12日,周四, {'29128': '浙江广厦控股'} vs. {'29116': '八一南昌'}, 100025981
# -----------------------------
# Scraping round 16, 12月12日,周四, {'29129': '辽宁本钢'} vs. {'29125': '上海久事'}, 100025982
# -----------------------------
# Scraping round 16, 12月12日,周四, {'29137': '九台农商银行'} vs. {'29133': '南京同曦宙光'}, 100025983
# -----------------------------
# Scraping round 16, 12月12日,周四, {'29134': '福建豹发力'} vs. {'29115': '北京首钢'}, 100025985
# -----------------------------
# Scraping round 16, 12月12日,周四, {'29124': '广东东莞银行'} vs. {'29140': '浙江稠州银行'}, 100025988
# -----------------------------
# Scraping round 16, 12月12日,周四, {'29130': '山东西王'} vs. {'29132': '山西汾酒股份'}, 100025990
# -----------------------------
# Scraping round 16, 12月13日,周五, {'29127': '四川五粮金樽'} vs. {'29118': '苏州肯帝亚'}, 100025992
# -----------------------------
# Scraping round 16, 12月13日,周五, {'29131': '深圳马可波罗'} vs. {'29138': '天津先行者'}, 100025994
# -----------------------------
# Round 16, 03月10日,周二, {'29117': '新疆伊力特'} vs. {'29135': '青岛国信双星'} 未开始，跳过
# Scraping round 17, 12月14日,周六, {'29125': '上海久事'} vs. {'29115': '北京首钢'}, 100025998
# -----------------------------
# Scraping round 17, 12月14日,周六, {'29133': '南京同曦宙光'} vs. {'29139': '时代中国广州'}, 100026000
# -----------------------------
# Scraping round 17, 12月14日,周六, {'29140': '浙江稠州银行'} vs. {'29128': '浙江广厦控股'}, 100026002
# -----------------------------
# Scraping round 17, 12月14日,周六, {'29129': '辽宁本钢'} vs. {'29137': '九台农商银行'}, 100026004
# -----------------------------
# Scraping round 17, 12月15日,周日, {'29138': '天津先行者'} vs. {'29118': '苏州肯帝亚'}, 100026006
# -----------------------------
# Scraping round 17, 12月15日,周日, {'29136': '北京控股'} vs. {'29124': '广东东莞银行'}, 100026009
# -----------------------------
# Scraping round 17, 12月15日,周日, {'29131': '深圳马可波罗'} vs. {'29134': '福建豹发力'}, 100026010
# -----------------------------
# Scraping round 17, 12月15日,周日, {'29116': '八一南昌'} vs. {'29127': '四川五粮金樽'}, 100026012
# -----------------------------
# Scraping round 17, 12月15日,周日, {'29135': '青岛国信双星'} vs. {'29132': '山西汾酒股份'}, 100026014
# -----------------------------
# Scraping round 17, 12月15日,周日, {'29117': '新疆伊力特'} vs. {'29130': '山东西王'}, 100026017
# -----------------------------
# Scraping round 18, 12月17日,周二, {'29118': '苏州肯帝亚'} vs. {'29124': '广东东莞银行'}, 100026019
# -----------------------------
# Scraping round 18, 12月17日,周二, {'29127': '四川五粮金樽'} vs. {'29130': '山东西王'}, 100026020
# -----------------------------
# Scraping round 18, 12月17日,周二, {'29139': '时代中国广州'} vs. {'29134': '福建豹发力'}, 100026022
# -----------------------------
# Scraping round 18, 12月17日,周二, {'29115': '北京首钢'} vs. {'29128': '浙江广厦控股'}, 100026024
# -----------------------------
# Scraping round 18, 12月17日,周二, {'29135': '青岛国信双星'} vs. {'29129': '辽宁本钢'}, 100026025
# -----------------------------
# Scraping round 18, 12月17日,周二, {'29137': '九台农商银行'} vs. {'29131': '深圳马可波罗'}, 100026026
# -----------------------------
# Scraping round 18, 12月17日,周二, {'29116': '八一南昌'} vs. {'29117': '新疆伊力特'}, 100026028
# -----------------------------
# Scraping round 18, 12月17日,周二, {'29138': '天津先行者'} vs. {'29133': '南京同曦宙光'}, 100026031
# -----------------------------
# Scraping round 18, 12月17日,周二, {'29125': '上海久事'} vs. {'29136': '北京控股'}, 100026032
# -----------------------------
# Scraping round 18, 12月18日,周三, {'29132': '山西汾酒股份'} vs. {'29140': '浙江稠州银行'}, 100026038
# -----------------------------
# Scraping round 19, 12月19日,周四, {'29118': '苏州肯帝亚'} vs. {'29139': '时代中国广州'}, 100026042
# -----------------------------
# Scraping round 19, 12月19日,周四, {'29127': '四川五粮金樽'} vs. {'29128': '浙江广厦控股'}, 100026045
# -----------------------------
# Scraping round 19, 12月19日,周四, {'29130': '山东西王'} vs. {'29129': '辽宁本钢'}, 100026048
# -----------------------------
# Scraping round 19, 12月19日,周四, {'29136': '北京控股'} vs. {'29135': '青岛国信双星'}, 100026050
# -----------------------------
# Scraping round 19, 12月19日,周四, {'29117': '新疆伊力特'} vs. {'29133': '南京同曦宙光'}, 100026053
# -----------------------------
# Scraping round 19, 12月20日,周五, {'29134': '福建豹发力'} vs. {'29137': '九台农商银行'}, 100026057
# -----------------------------
# Scraping round 19, 12月20日,周五, {'29115': '北京首钢'} vs. {'29140': '浙江稠州银行'}, 100026058
# -----------------------------
# Scraping round 19, 12月20日,周五, {'29132': '山西汾酒股份'} vs. {'29131': '深圳马可波罗'}, 100026059
# -----------------------------
# Scraping round 19, 12月20日,周五, {'29125': '上海久事'} vs. {'29116': '八一南昌'}, 100026062
# -----------------------------
# Scraping round 19, 12月20日,周五, {'29124': '广东东莞银行'} vs. {'29138': '天津先行者'}, 100026065
# -----------------------------
# Scraping round 20, 12月21日,周六, {'29136': '北京控股'} vs. {'29118': '苏州肯帝亚'}, 100026068
# -----------------------------
# Scraping round 20, 12月22日,周日, {'29127': '四川五粮金樽'} vs. {'29140': '浙江稠州银行'}, 100026072
# -----------------------------
# Scraping round 20, 12月22日,周日, {'29132': '山西汾酒股份'} vs. {'29115': '北京首钢'}, 100026076
# -----------------------------
# Scraping round 20, 12月22日,周日, {'29131': '深圳马可波罗'} vs. {'29130': '山东西王'}, 100026080
# -----------------------------
# Scraping round 20, 12月22日,周日, {'29138': '天津先行者'} vs. {'29135': '青岛国信双星'}, 100026092
# -----------------------------
# Scraping round 20, 12月22日,周日, {'29128': '浙江广厦控股'} vs. {'29137': '九台农商银行'}, 100026095
# -----------------------------
# Scraping round 20, 12月22日,周日, {'29139': '时代中国广州'} vs. {'29124': '广东东莞银行'}, 100026099
# -----------------------------
# Scraping round 20, 12月22日,周日, {'29116': '八一南昌'} vs. {'29133': '南京同曦宙光'}, 100026110
# -----------------------------
# Scraping round 20, 12月22日,周日, {'29134': '福建豹发力'} vs. {'29129': '辽宁本钢'}, 100026114
# -----------------------------
# Scraping round 20, 12月22日,周日, {'29117': '新疆伊力特'} vs. {'29125': '上海久事'}, 100026116
# -----------------------------
# Scraping round 21, 12月24日,周二, {'29138': '天津先行者'} vs. {'29130': '山东西王'}, 100025850
# -----------------------------
# Scraping round 21, 12月24日,周二, {'29128': '浙江广厦控股'} vs. {'29129': '辽宁本钢'}, 100025853
# -----------------------------
# Scraping round 21, 12月25日,周三, {'29131': '深圳马可波罗'} vs. {'29118': '苏州肯帝亚'}, 100025863
# -----------------------------
# Scraping round 21, 12月25日,周三, {'29140': '浙江稠州银行'} vs. {'29139': '时代中国广州'}, 100025868
# -----------------------------
# Scraping round 21, 12月25日,周三, {'29137': '九台农商银行'} vs. {'29135': '青岛国信双星'}, 100025870
# -----------------------------
# Scraping round 21, 12月25日,周三, {'29115': '北京首钢'} vs. {'29117': '新疆伊力特'}, 100025884
# -----------------------------
# Scraping round 21, 12月26日,周四, {'29124': '广东东莞银行'} vs. {'29125': '上海久事'}, 100025886
# -----------------------------
# Scraping round 21, 12月26日,周四, {'29133': '南京同曦宙光'} vs. {'29136': '北京控股'}, 100025894
# -----------------------------
# Scraping round 21, 12月26日,周四, {'29116': '八一南昌'} vs. {'29132': '山西汾酒股份'}, 100025898
# -----------------------------
# Scraping round 21, 01月09日,周四, {'29134': '福建豹发力'} vs. {'29127': '四川五粮金樽'}, 100025900
# -----------------------------
# Scraping round 22, 12月27日,周五, {'29139': '时代中国广州'} vs. {'29128': '浙江广厦控股'}, 100025906
# -----------------------------
# Scraping round 22, 12月27日,周五, {'29140': '浙江稠州银行'} vs. {'29131': '深圳马可波罗'}, 100025910
# -----------------------------
# Scraping round 22, 12月28日,周六, {'29133': '南京同曦宙光'} vs. {'29115': '北京首钢'}, 100025914
# -----------------------------
# Scraping round 22, 12月28日,周六, {'29116': '八一南昌'} vs. {'29136': '北京控股'}, 100025925
# -----------------------------
# Scraping round 22, 12月28日,周六, {'29137': '九台农商银行'} vs. {'29130': '山东西王'}, 100025940
# -----------------------------
# Scraping round 22, 12月28日,周六, {'29138': '天津先行者'} vs. {'29134': '福建豹发力'}, 100025946
# -----------------------------
# Scraping round 22, 12月29日,周日, {'29125': '上海久事'} vs. {'29127': '四川五粮金樽'}, 100025950
# -----------------------------
# Scraping round 22, 12月29日,周日, {'29129': '辽宁本钢'} vs. {'29132': '山西汾酒股份'}, 100025955
# -----------------------------
# Scraping round 22, 12月29日,周日, {'29135': '青岛国信双星'} vs. {'29117': '新疆伊力特'}, 100026008
# -----------------------------
# Scraping round 22, 12月29日,周日, {'29124': '广东东莞银行'} vs. {'29118': '苏州肯帝亚'}, 100026013
# -----------------------------
# Scraping round 23, 12月31日,周二, {'29127': '四川五粮金樽'} vs. {'29115': '北京首钢'}, 100026027
# -----------------------------
# Scraping round 23, 12月31日,周二, {'29138': '天津先行者'} vs. {'29117': '新疆伊力特'}, 100026035
# -----------------------------
# Scraping round 23, 12月31日,周二, {'29130': '山东西王'} vs. {'29134': '福建豹发力'}, 100026039
# -----------------------------
# Scraping round 23, 12月31日,周二, {'29136': '北京控股'} vs. {'29132': '山西汾酒股份'}, 100026046
# -----------------------------
# Scraping round 23, 12月31日,周二, {'29139': '时代中国广州'} vs. {'29137': '九台农商银行'}, 100026055
# -----------------------------
# Scraping round 23, 12月31日,周二, {'29128': '浙江广厦控股'} vs. {'29133': '南京同曦宙光'}, 100026060
# -----------------------------
# Scraping round 23, 12月31日,周二, {'29135': '青岛国信双星'} vs. {'29116': '八一南昌'}, 100026069
# -----------------------------
# Scraping round 23, 01月01日,周三, {'29118': '苏州肯帝亚'} vs. {'29129': '辽宁本钢'}, 100026077
# -----------------------------
# Scraping round 23, 01月01日,周三, {'29125': '上海久事'} vs. {'29140': '浙江稠州银行'}, 100026082
# -----------------------------
# Scraping round 23, 01月01日,周三, {'29124': '广东东莞银行'} vs. {'29131': '深圳马可波罗'}, 100026087
# -----------------------------
# Scraping round 24, 01月02日,周四, {'29115': '北京首钢'} vs. {'29138': '天津先行者'}, 100026094
# -----------------------------
# Scraping round 24, 01月02日,周四, {'29132': '山西汾酒股份'} vs. {'29139': '时代中国广州'}, 100026100
# -----------------------------
# Scraping round 24, 01月02日,周四, {'29116': '八一南昌'} vs. {'29130': '山东西王'}, 100026109
# -----------------------------
# Scraping round 24, 01月02日,周四, {'29137': '九台农商银行'} vs. {'29135': '青岛国信双星'}, 100026118
# -----------------------------
# Scraping round 24, 01月02日,周四, {'29134': '福建豹发力'} vs. {'29128': '浙江广厦控股'}, 100026127
# -----------------------------
# Scraping round 24, 01月02日,周四, {'29117': '新疆伊力特'} vs. {'29127': '四川五粮金樽'}, 100026132
# -----------------------------
# Scraping round 24, 01月03日,周五, {'29131': '深圳马可波罗'} vs. {'29136': '北京控股'}, 100026137
# -----------------------------
# Scraping round 24, 01月03日,周五, {'29133': '南京同曦宙光'} vs. {'29125': '上海久事'}, 100026169
# -----------------------------
# Scraping round 24, 01月03日,周五, {'29140': '浙江稠州银行'} vs. {'29118': '苏州肯帝亚'}, 100026179
# -----------------------------
# Scraping round 24, 01月03日,周五, {'29129': '辽宁本钢'} vs. {'29124': '广东东莞银行'}, 100026196
# -----------------------------
# Scraping round 25, 01月04日,周六, {'29130': '山东西王'} vs. {'29115': '北京首钢'}, 100026200
# -----------------------------
# Scraping round 25, 01月04日,周六, {'29116': '八一南昌'} vs. {'29135': '青岛国信双星'}, 100026203
# -----------------------------
# Scraping round 25, 01月04日,周六, {'29137': '九台农商银行'} vs. {'29138': '天津先行者'}, 100026206
# -----------------------------
# Scraping round 25, 01月04日,周六, {'29134': '福建豹发力'} vs. {'29132': '山西汾酒股份'}, 100026208
# -----------------------------
# Scraping round 25, 01月05日,周日, {'29118': '苏州肯帝亚'} vs. {'29133': '南京同曦宙光'}, 100026211
# -----------------------------
# Scraping round 25, 01月05日,周日, {'29127': '四川五粮金樽'} vs. {'29124': '广东东莞银行'}, 100026213
# -----------------------------
# Scraping round 25, 01月05日,周日, {'29131': '深圳马可波罗'} vs. {'29139': '时代中国广州'}, 100026217
# -----------------------------
# Scraping round 25, 01月05日,周日, {'29125': '上海久事'} vs. {'29136': '北京控股'}, 100026220
# -----------------------------
# Scraping round 25, 01月05日,周日, {'29140': '浙江稠州银行'} vs. {'29117': '新疆伊力特'}, 100026223
# -----------------------------
# Scraping round 25, 01月05日,周日, {'29128': '浙江广厦控股'} vs. {'29129': '辽宁本钢'}, 100026224
# -----------------------------
# Scraping round 26, 01月07日,周二, {'29127': '四川五粮金樽'} vs. {'29133': '南京同曦宙光'}, 100026225
# -----------------------------
# Scraping round 26, 01月07日,周二, {'29138': '天津先行者'} vs. {'29118': '苏州肯帝亚'}, 100026228
# -----------------------------
# Scraping round 26, 01月07日,周二, {'29130': '山东西王'} vs. {'29124': '广东东莞银行'}, 100026231
# -----------------------------
# Scraping round 26, 01月07日,周二, {'29139': '时代中国广州'} vs. {'29136': '北京控股'}, 100026233
# -----------------------------
# Scraping round 26, 01月07日,周二, {'29125': '上海久事'} vs. {'29115': '北京首钢'}, 100026234
# -----------------------------
# Scraping round 26, 01月07日,周二, {'29131': '深圳马可波罗'} vs. {'29129': '辽宁本钢'}, 100026235
# -----------------------------
# Scraping round 26, 01月07日,周二, {'29132': '山西汾酒股份'} vs. {'29140': '浙江稠州银行'}, 100026237
# -----------------------------
# Scraping round 26, 01月07日,周二, {'29128': '浙江广厦控股'} vs. {'29117': '新疆伊力特'}, 100026238
# -----------------------------
# Scraping round 26, 01月07日,周二, {'29116': '八一南昌'} vs. {'29137': '九台农商银行'}, 100026240
# -----------------------------
# Scraping round 26, 01月07日,周二, {'29135': '青岛国信双星'} vs. {'29134': '福建豹发力'}, 100026243
# -----------------------------
# Scraping round 27, 01月14日,周二, {'29127': '四川五粮金樽'} vs. {'29118': '苏州肯帝亚'}, 100026249
# -----------------------------
# Scraping round 27, 01月14日,周二, {'29138': '天津先行者'} vs. {'29125': '上海久事'}, 100026255
# -----------------------------
# Scraping round 27, 01月14日,周二, {'29140': '浙江稠州银行'} vs. {'29133': '南京同曦宙光'}, 100026256
# -----------------------------
# Scraping round 27, 01月14日,周二, {'29132': '山西汾酒股份'} vs. {'29128': '浙江广厦控股'}, 100026258
# -----------------------------
# Scraping round 27, 01月14日,周二, {'29116': '八一南昌'} vs. {'29129': '辽宁本钢'}, 100026263
# -----------------------------
# Scraping round 27, 01月14日,周二, {'29117': '新疆伊力特'} vs. {'29134': '福建豹发力'}, 100026267
# -----------------------------
# Scraping round 27, 01月14日,周二, {'29124': '广东东莞银行'} vs. {'29137': '九台农商银行'}, 100026272
# -----------------------------
# Scraping round 27, 01月14日,周二, {'29139': '时代中国广州'} vs. {'29130': '山东西王'}, 100026275
# -----------------------------
# Scraping round 27, 01月15日,周三, {'29136': '北京控股'} vs. {'29131': '深圳马可波罗'}, 100026276
# -----------------------------
# Scraping round 27, 01月15日,周三, {'29135': '青岛国信双星'} vs. {'29115': '北京首钢'}, 100026277
# -----------------------------
# Scraping round 28, 01月16日,周四, {'29118': '苏州肯帝亚'} vs. {'29128': '浙江广厦控股'}, 100026278
# -----------------------------
# Scraping round 28, 01月16日,周四, {'29125': '上海久事'} vs. {'29132': '山西汾酒股份'}, 100026279
# -----------------------------
# Scraping round 28, 01月16日,周四, {'29133': '南京同曦宙光'} vs. {'29129': '辽宁本钢'}, 100026280
# -----------------------------
# Scraping round 28, 01月16日,周四, {'29138': '天津先行者'} vs. {'29130': '山东西王'}, 100026281
# -----------------------------
# Scraping round 28, 01月16日,周四, {'29124': '广东东莞银行'} vs. {'29127': '四川五粮金樽'}, 100026282
# -----------------------------
# Scraping round 28, 01月17日,周五, {'29134': '福建豹发力'} vs. {'29116': '八一南昌'}, 100026283
# -----------------------------
# Scraping round 28, 01月17日,周五, {'29137': '九台农商银行'} vs. {'29117': '新疆伊力特'}, 100026284
# -----------------------------
# Scraping round 28, 01月17日,周五, {'29139': '时代中国广州'} vs. {'29135': '青岛国信双星'}, 100026285
# -----------------------------
# Scraping round 28, 01月17日,周五, {'29115': '北京首钢'} vs. {'29131': '深圳马可波罗'}, 100026286
# -----------------------------
# Scraping round 28, 01月17日,周五, {'29140': '浙江稠州银行'} vs. {'29136': '北京控股'}, 100026287
# -----------------------------
# Scraping round 29, 01月18日,周六, {'29124': '广东东莞银行'} vs. {'29130': '山东西王'}, 100026288
# -----------------------------
# Scraping round 29, 01月18日,周六, {'29133': '南京同曦宙光'} vs. {'29132': '山西汾酒股份'}, 100026289
# -----------------------------
# Scraping round 29, 01月19日,周日, {'29129': '辽宁本钢'} vs. {'29117': '新疆伊力特'}, 100026290
# -----------------------------
# Scraping round 29, 01月19日,周日, {'29137': '九台农商银行'} vs. {'29116': '八一南昌'}, 100026291
# -----------------------------
# Scraping round 29, 01月19日,周日, {'29139': '时代中国广州'} vs. {'29127': '四川五粮金樽'}, 100026292
# -----------------------------
# Scraping round 29, 01月19日,周日, {'29125': '上海久事'} vs. {'29131': '深圳马可波罗'}, 100026293
# -----------------------------
# Scraping round 29, 01月19日,周日, {'29115': '北京首钢'} vs. {'29118': '苏州肯帝亚'}, 100026294
# -----------------------------
# Scraping round 29, 01月19日,周日, {'29140': '浙江稠州银行'} vs. {'29138': '天津先行者'}, 100026295
# -----------------------------
# Scraping round 29, 01月19日,周日, {'29128': '浙江广厦控股'} vs. {'29136': '北京控股'}, 100026296
# -----------------------------
# Scraping round 29, 01月19日,周日, {'29134': '福建豹发力'} vs. {'29135': '青岛国信双星'}, 100026297
# -----------------------------
# Complete!

# %%
df_all_events =pd.DataFrame(all_plays)
df_all_events
# Out:
#        eventid teamid shotcoordx shotcoordy eventtypeid quarternum minutes  \
# 0                   0          0          0          19          4       0
# 1                   0          0          0          15          4       0
# 2               29129    14.9722      15.54           4          4       0
# 3               29124     3.3272      -0.78           3          4       0
# 4               29129    -1.5123      21.78           4          4       0
# ...        ...    ...        ...        ...         ...        ...     ...
# 100725          29135          0          0           7          1      11
# 100726          29134    -2.7222    -1.3462           3          1      11
# 100727          29135    13.6111    19.0385           4          1      11
# 100728          29134          0          0          12          1      12
# 100729              0          0          0          14          1      12
#
#        seconds                    class quarter          style  \
# 0            0  [quarterSet, quarter_4]       4  width: 500px;
# 1            0  [quarterSet, quarter_4]       4  width: 500px;
# 2            1  [quarterSet, quarter_4]       4  width: 500px;
# 3           10  [quarterSet, quarter_4]       4  width: 500px;
# 4           29  [quarterSet, quarter_4]       4  width: 500px;
# ...        ...                      ...     ...            ...
# 100725      10  [quarterSet, quarter_1]       1  width: 500px;
# 100726      28  [quarterSet, quarter_1]       1  width: 500px;
# 100727      43  [quarterSet, quarter_1]       1  width: 500px;
# 100728       0  [quarterSet, quarter_1]       1  width: 500px;
# 100729       0  [quarterSet, quarter_1]       1  width: 500px;
#
#                           event   score shotevent
# 0                          比赛结束  107:98       NaN
# 1                         第4节结束  107:98       NaN
# 2          史蒂芬森三分跳投不中，易建联获得防守篮板  107:98
# 3           任骏飞接到易建联的助攻，跳投，命中得分  107:98
# 4       高诗岩三分跳投不中，广东东莞银行队获得防守篮板  105:98
# ...                         ...     ...       ...
# 100725                    许家晗失误     2:0       NaN
# 100726               王哲林跳投，命中得分     2:0
# 100727   亚当斯三分跳投不中，福建豹发力队获得防守篮板     0:0
# 100728    王哲林和刘传兴跳球，青岛国信双星队得到球权     0:0       NaN
# 100729                    第1节开始     0:0       NaN
#
# [100730 rows x 14 columns]

# %%
df_all_events.sort_values(by=['eventtypeid']).to_csv('AllPlays_2020-01-20_until_round29.csv')

# %% [markdown]
# # Drawing

# %%
df_all_events.columns
# Out:
# Index(['eventid', 'teamid', 'shotcoordx', 'shotcoordy', 'eventtypeid',
#        'quarternum', 'minutes', 'seconds', 'class', 'quarter', 'style',
#        'event', 'score', 'shotevent'],
#       dtype='object')

# %%
shooting_events = df_all_events[['teamid','shotcoordx','shotcoordy',
                                 'eventtypeid','quarternum', 'minutes', 'seconds',
                                'event', 'score']].copy()

# %%
shooting_events = shooting_events.loc[shooting_events['eventtypeid'].isin(['3','4']),:].copy()

# %%
shooting_events['shotcoordx'] = shooting_events['shotcoordx'].astype('float')
shooting_events['shotcoordy'] = shooting_events['shotcoordy'].astype('float')

# %%
shooting_events[['shotcoordx','shotcoordy']].max()
# Out:
# shotcoordx    23.4523
# shotcoordy    69.0201
# dtype: float64

# %%
shooting_events[['shotcoordx','shotcoordy']].min()
# Out:
# shotcoordx   -24.5
# shotcoordy    -7.5
# dtype: float64

# %%
shooting_events
# Out:
#        teamid shotcoordx shotcoordy eventtypeid quarternum minutes seconds  \
# 2       29129    14.9722      15.54           4          4       0       1
# 3       29124     3.3272      -0.78           3          4       0      10
# 4       29129    -1.5123      21.78           4          4       0      29
# 8       29129    -3.6296      20.66           3          4       0      40
# 9       29124     3.9321       -1.1           3          4       0      51
# ...       ...        ...        ...         ...        ...     ...     ...
# 100720  29134    -6.2309    22.8846           4          1      10      29
# 100721  29135    18.4506    12.3718           3          1      10      44
# 100724  29134    -1.7543     -1.859           3          1      10      55
# 100726  29134    -2.7222    -1.3462           3          1      11      28
# 100727  29135    13.6111    19.0385           4          1      11      43
#
#                           event   score
# 2          史蒂芬森三分跳投不中，易建联获得防守篮板  107:98
# 3           任骏飞接到易建联的助攻，跳投，命中得分  107:98
# 4       高诗岩三分跳投不中，广东东莞银行队获得防守篮板  105:98
# 8                   史蒂芬森跳投，三分入网  103:98
# 9          易建联接到布鲁克斯的助攻，跳投，命中得分  103:95
# ...                         ...     ...
# 100720       杰特三分跳投不中，王庆明获得防守篮板     5:3
# 100721      王庆明接到许家晗的助攻，跳投，三分入网     5:3
# 100724               王哲林跳投，命中得分     4:0
# 100726               王哲林跳投，命中得分     2:0
# 100727   亚当斯三分跳投不中，福建豹发力队获得防守篮板     0:0
#
# [46322 rows x 9 columns]

# %%
def meter_to_coord(meter):
    return meter*49/15

# %%
28/15*49/2
# Out:
# 45.733333333333334

# %%
Blues8[1]
# Out:
# ['#084594',
#  '#2171b5',
#  '#4292c6',
#  '#6baed6',
#  '#9ecae1',
#  '#c6dbef',
#  '#deebf7',
#  '#f7fbff']

# %%
xj_shots = shooting_events.query("teamid=='29117'").copy()
xj_shots['color'] = Blues8[1]
xj_shots['fill_color'] = xj_shots['color']
xj_shots.loc[xj_shots['eventtypeid']=='4','fill_color']='white'

gd_shots = shooting_events.query("teamid=='29124'").copy()
gd_shots['color'] = Blues8[1]
gd_shots['fill_color'] = gd_shots['color']
# 没中则用白色填充
gd_shots.loc[gd_shots['eventtypeid']=='4','fill_color']='white'

# %% [raw]
# +--------+---------+---------+---------+---------+
# | 球队   |   2分中 |   2分投 |   3分中 |   3分投 |
# |--------+---------+---------+---------+---------|
# | 新疆   |     873 |    1496 |     316 |     895 |
# +--------+---------+---------+---------+---------+
# 数据共1行，4列.
# ----------Your data is a pandas dataframe----------
# +--------+---------+---------+---------+---------+
# | 球队   |   2分中 |   2分投 |   3分中 |   3分投 |
# |--------+---------+---------+---------+---------|
# | 广东   |     914 |    1554 |     369 |     925 |
# +--------+---------+---------+---------+---------+
# 数据共1行，4列.
# +-------+-------+
# | 2分中 | 16088 |
# | 2分投 | 30035 |
# | 3分中 |  5868 |
# | 3分投 | 16340 |
# +-------+-------+

# %%
print(f'广东{1554+925}投{914+369}中,3分投篮占比{925/(925+1554)*100:.2f}%')
# Out:
# 广东2479投1283中,3分投篮占比37.31

# %%
print(f'新疆{1496+895}投{873+316}中,3分投篮占比{895/(1496+895)*100:.2f}%')
# Out:
# 新疆2391投1189中,3分投篮占比37.43%

# %%
print(f'联盟{1496+895}投{873+316}中,3分投篮占比{16340/(30035+16340)*100:.2f}%')
# Out:
# 联盟2391投1189中,3分投篮占比35.23%

# %% [markdown]
# ### 球队分布

# %%
import math

# %%
def angle(vector1, vector2):
    x1, y1 = vector1
    x2, y2 = vector2
    inner_product = x1*x2 + y1*y2
    len1 = math.hypot(x1, y1)
    len2 = math.hypot(x2, y2)
    return math.acos(inner_product/(len1*len2))

# %%
angle((1,1),(-1,0))/pi*180
# Out:
# 135.0

# %%
endline_y = -7.5
halfcourtline_y=45.73
sideline_left = 24.5
rim_to_baseline=7.5
rim_x=0
rim_y=endline+meter_to_coord(1.2)
threepointline_radius = meter_to_coord(6.75)
nochargeline_rarius = meter_to_coord(1.25)
centercircle_radius = meter_to_coord(1.83)
rim_radius = meter_to_coord(0.23)
backboard_length = meter_to_coord(1.83)
restrictedarea_length = meter_to_coord(5.8)
restrictedarea_width = meter_to_coord(4.9)
ftline_length = meter_to_coord(3.6)


goal_color = Blues8[1]
miss_color = Reds6[0]
linewidth = 3
size = 9
alpha = 0.6

# %%
def draw_court(p):
    endline_y = -7.5
    halfcourtline_y=45.73
    sideline_left = 24.5
    rim_to_baseline=7.5
    rim_x=0
    rim_y=endline+meter_to_coord(1.2)
    threepointline_radius = meter_to_coord(6.75)
    nochargeline_rarius = meter_to_coord(1.25)
    centercircle_radius = meter_to_coord(1.83)
    rim_radius = meter_to_coord(0.23)
    backboard_length = meter_to_coord(1.83)
    restrictedarea_length = meter_to_coord(5.8)
    restrictedarea_width = meter_to_coord(4.9)
    ftline_length = meter_to_coord(3.6)


    goal_color = Blues8[1]
    miss_color = Reds6[0]
    linewidth = 3
    size = 9
    alpha = 0.6
    
    # 3p line
    p.arc(x=rim_x, y=rim_y, radius=threepointline_radius, start_angle=0, end_angle=pi,line_color='black', line_width=linewidth)

    # 左侧三分直线
    p.line(x=[-threepointline_radius,-threepointline_radius],y=[endline_y,rim_y],line_color='black', line_width=linewidth-0.1)

    # 右侧三分直线
    p.line(x=[threepointline_radius,threepointline_radius],y=[endline_y,rim_y],line_color='black', line_width=linewidth-0.1)

    # 合理冲撞区
    p.arc(x=rim_x, y=rim_y, radius=nochargeline_rarius, start_angle=0, end_angle=pi,line_color='black', line_width=linewidth)

    # 中圈
    p.arc(x=rim_x, y=halfcourtline_y, radius=centercircle_radius, start_angle=pi, end_angle=0,line_color='black', line_width=linewidth)

    # 篮筐
    p.circle(x=0,y=rim_y,radius = rim_radius,color='red',fill_color=None,line_width=linewidth)


    # 篮板
    p.line(x=[-backboard_length/2,backboard_length/2],
           y=[rim_y-rim_radius-0.3,rim_y-rim_radius-0.3],
           line_color='black', line_width=linewidth)

    #场地边线
    p.quad(-sideline_left,sideline_left,halfcourtline_y,endline_y,fill_color=None,line_color='black',
          line_width=linewidth)

    #限制区
    p.quad(-restrictedarea_width/2,restrictedarea_width/2,endline_y+restrictedarea_length,endline_y,fill_color=None,line_color='black',
          line_width=linewidth)

    #罚球区
    p.arc(x=rim_x, y=endline_y+restrictedarea_length, radius=ftline_length/2, start_angle=0, end_angle=pi,line_color='black', line_width=linewidth)

# %%
from bokeh.models.glyphs import Arc
from math import pi

output_notebook()

# create a new plot
p = figure(
   title="广东19-20赛季投篮分布--2479投1283中，3分投篮占比37.31%",tools="pan,box_zoom,wheel_zoom,save,reset,hover",
    x_range=[-sideline_left,sideline_left],y_range = [endline_y,hafcourtline_y],x_axis_label='x',y_axis_label='y'
)


p.axis.visible = False
p.grid.visible = False

# misses
p.cross(gd_shots.loc[gd_shots['eventtypeid']=='4','shotcoordx'],gd_shots.loc[gd_shots['eventtypeid']=='4','shotcoordy'],
        angle=90,color=miss_color, size=size,alpha=alpha,legend_label='未命中')

# goals
p.circle(gd_shots.loc[gd_shots['eventtypeid']=='3','shotcoordx'], gd_shots.loc[gd_shots['eventtypeid']=='3','shotcoordy'], 
         fill_color=goal_color,color=goal_color, size=size,alpha=alpha,legend_label='命中')

draw_court(p)

# show the results
show(p)

#width: 15m, 50
#length: 28m，
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="93082">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="540df5f4-ac7a-429e-b3d7-682f4e968331" data-root-id="93083"></div>

# %%
# output to static HTML file
output_notebook()

# create a new plot
p = figure(
   title="新疆19-20赛季投篮分布--2391投1189中，3分投篮占比37.43%",tools="pan,box_zoom,wheel_zoom,save,reset,hover",
    x_range=[-24.5,24.5],y_range = [-7.5,45.73],x_axis_label='xxx',y_axis_label='yyy'
)
p.axis.visible = False

# misses
p.cross(xj_shots.loc[xj_shots['eventtypeid']=='4','shotcoordx'],xj_shots.loc[xj_shots['eventtypeid']=='4','shotcoordy'],
        angle=90,color=miss_color, size=size,alpha=alpha,legend_label='未命中')

# goals
p.circle(xj_shots.loc[xj_shots['eventtypeid']=='3','shotcoordx'], xj_shots.loc[xj_shots['eventtypeid']=='3','shotcoordy'], 
         fill_color=goal_color,color=goal_color, size=size,alpha=alpha,legend_label='命中')

draw_court(p)

# show the results
show(p)

#width: 15m, 50
#length: 28m，
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="93948">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="18b70027-9cfd-495c-aed6-01f9ad38a9bf" data-root-id="93949"></div>

# %% [markdown]
# ### 周琦vs易建联

# %%
zq_shots = xj_shots.loc[(xj_shots['event'].str.contains('周琦'))&(-xj_shots['event'].str.contains('周琦抢到'))&(-(xj_shots['event'].str.contains('周琦的助攻'))),:].copy()

# %%
yjl_shots = gd_shots.loc[(gd_shots['event'].str.contains('易建联'))&(-gd_shots['event'].str.contains('易建联抢到'))&(-(gd_shots['event'].str.contains('易建联的助攻'))),:].copy()

# %% [raw]
# +--------------------+---------+---------+---------+---------+
# |                    |   2分中 |   2分投 |   3分中 |   3分投 |
# |--------------------+---------+---------+---------+---------|
# | ('易建联', '广东') |     168 |     296 |      34 |      94 |
# +--------------------+---------+---------+---------+---------+
# 数据共1行，4列.
# ----------Your data is a pandas dataframe----------
# +------------------+---------+---------+---------+---------+
# |                  |   2分中 |   2分投 |   3分中 |   3分投 |
# |------------------+---------+---------+---------+---------|
# | ('周琦', '新疆') |     157 |     243 |      33 |     103 |
# +------------------+---------+---------+---------+---------+

# %%
print(f'易建联共{296+94}投{168+34}中，总命中率{(168+34)/(296+94)*100:.2f}%，3分投篮占比{94/(296+94)*100:.2f}%')
# Out:
# 易建联共390投202中，总命中率51.79%，3分投篮占比24.10%

# %%
print(f'周琦共{243+103}投{33+157}中，总命中率{(33+157)/(243+103)*100:.2f}%，3分投篮占比{103/(243+103)*100:.2f}%')
# Out:
# 周琦共346投190中，总命中率54.91%，3分投篮占比29.77%

# %%
from bokeh.models.glyphs import Arc
from math import pi

# prepare some data

# output to static HTML file
output_notebook()

# create a new plot
p = figure(
   title="周琦19-20赛季投篮分布--共346投190中，总命中率54.91%，3分投篮占比29.77%",tools="pan,box_zoom,wheel_zoom,save,reset,hover",
    x_range=[-24.5,24.5],y_range = [-7.5,45.73],x_axis_label='x',y_axis_label='y'
)

p.axis.visible = False

# misses
p.cross(zq_shots.loc[zq_shots['eventtypeid']=='4','shotcoordx'],zq_shots.loc[zq_shots['eventtypeid']=='4','shotcoordy'],
        angle=90,color=miss_color, size=10,alpha=alpha,legend_label='未命中')

# goals
p.circle(zq_shots.loc[zq_shots['eventtypeid']=='3','shotcoordx'], zq_shots.loc[zq_shots['eventtypeid']=='3','shotcoordy'], 
         fill_color=goal_color,color=goal_color, size=10,alpha=alpha,legend_label='命中')

draw_court(p)

# show the results
show(p)

#width: 15m, 50
#length: 28m，
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="94844">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="cac38ea5-f586-48dc-ab59-154474dbd71a" data-root-id="94845"></div>

# %%
# prepare some data

# output to static HTML file
output_notebook()

# create a new plot
p = figure(
   title="易建联19-20赛季投篮分布--共390投202中，总命中率51.79%，3分投篮占比24.10%",tools="pan,box_zoom,wheel_zoom,save,reset,hover",
    x_range=[-24.5,24.5],y_range = [-7.5,45.73],x_axis_label='xxx',y_axis_label='yyy'
)
p.axis.visible = False

# misses
p.cross(yjl_shots.loc[yjl_shots['eventtypeid']=='4','shotcoordx'],yjl_shots.loc[yjl_shots['eventtypeid']=='4','shotcoordy'],
        angle=90,color=miss_color, size=10,alpha=alpha,legend_label='未命中')

# goals
p.circle(yjl_shots.loc[yjl_shots['eventtypeid']=='3','shotcoordx'], yjl_shots.loc[yjl_shots['eventtypeid']=='3','shotcoordy'], 
         fill_color=goal_color,color=goal_color, size=10,alpha=alpha,legend_label='命中')

draw_court(p)

# show the results
show(p)

#width: 15m, 50
#length: 28m，
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="95770">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="bf2b6ce1-39ab-44ac-8258-9425e2566ae6" data-root-id="95771"></div>
