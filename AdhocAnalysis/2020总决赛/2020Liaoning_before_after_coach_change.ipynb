# %%
from cbastats.Team import *
from cbastats.Player import *
from sqlalchemy import create_engine
import datetime

# %%
print('最近一次运行时间：',datetime.datetime.now())
# Out:
# 最近一次运行时间： 2020-08-04 01:10:56.588501

# %% [markdown]
# # 载入数据

# %%
user_name = 'guest'
passcode = 'Guest123456'
endpoint = 'cbashuju.ctkaehd5rxxe.us-east-1.rds.amazonaws.com'
database = 'CBA_Data'
engine = create_engine(f'mysql+pymysql://{user_name}:{passcode}@{endpoint}/{database}')

connection= engine.connect()

# %%
df = pd.read_sql("select * from CBA_Data.PlayerStatsPerGame", connection);

# %%
connection.close()

# %%
whole_season = df
before_change = df.loc[df['Game_ID']<'2019202000343'].copy()
after_change = df.loc[df['Game_ID']>='2019202000343'].copy()

# %% [markdown]
# # 整个赛季所有球队数据
#
# ### 综合整个赛季来看，广东新疆辽宁三强net rating和新浪积分榜排名相符。
# 新浪积分榜 http://cba.sports.sina.com.cn/cba/stats/teamrank/?dpc=1

# %%
# 整个赛季数据
teams = Team('',whole_season)

teams_whole_season = pd.concat([teams.mov, teams.tm_pace, teams.tm_ortg, teams.tm_drtg, teams.tm_nrtg], axis=1)
teams_whole_season.columns=['场均净胜分MOV', 'Pace', 'OffensiveRating', 'DefensiveRating', 'NetRating']
teams_whole_season = teams_whole_season.sort_values(by='NetRating',ascending=False)
teams_whole_season.rename(index={'辽宁':"辽宁（整赛季）"},inplace=True)
print('本赛季辽宁共打了'+str(teams.tm_ngames['辽宁'])+"场比赛")
teams_whole_season.round(1)
# Out:
# 本赛季辽宁共打了47.0场比赛
#          场均净胜分MOV  Pace  OffensiveRating  DefensiveRating  NetRating
# 球队
# 广东           20.3  98.3            125.9            104.8       21.2
# 新疆           11.3  94.8            118.4            106.3       12.1
# 辽宁（整赛季）       8.4  94.7            120.0            111.0        9.0
# 浙江            6.6  92.3            120.3            113.0        7.3
# 北京            5.3  88.5            110.4            104.3        6.1
# 广厦            5.5  95.2            113.5            107.6        5.9
# 青岛            1.5  94.8            114.7            113.0        1.7
# 山东            1.2  92.0            113.1            111.8        1.3
# 吉林            1.0  92.2            115.8            114.7        1.1
# 北控            0.7  93.6            110.9            110.2        0.7
# 福建            0.2  96.5            117.7            117.5        0.2
# 山西           -0.4  91.4            111.9            112.3       -0.4
# ...

# %% [markdown]
# # 换帅前数据
#
# ### 然而，假如我们只截取辽宁换帅前的比赛数据（换帅前，辽宁共打了34场比赛），辽宁的净效率排名只有第7。

# %%
teams = Team('',before_change)

teams_before_change = pd.concat([teams.mov, teams.tm_pace, teams.tm_ortg, teams.tm_drtg, teams.tm_nrtg], axis=1)
teams_before_change.columns=['场均净胜分MOV', 'Pace', 'OffensiveRating', 'DefensiveRating', 'NetRating']
teams_before_change = teams_before_change.sort_values(by='NetRating',ascending=False)
teams_before_change.rename(index={'辽宁':"辽宁（换帅前）"},inplace=True)
print('换帅前辽宁共打了'+str(teams.tm_ngames['辽宁'])+"场比赛")
teams_before_change.round(1)
# Out:
# 换帅前辽宁共打了34.0场比赛
#          场均净胜分MOV  Pace  OffensiveRating  DefensiveRating  NetRating
# 球队
# 广东           19.6  97.6            127.2            106.5       20.7
# 新疆            9.3  95.1            120.5            110.6        9.9
# 广厦            5.8  94.9            113.7            107.5        6.2
# 浙江            5.4  92.3            122.1            116.1        6.0
# 青岛            5.0  95.3            119.1            113.7        5.4
# 吉林            3.8  92.2            119.2            114.9        4.2
# 辽宁（换帅前）       3.8  94.0            117.4            113.3        4.1
# 山东            3.5  91.7            115.7            111.8        3.9
# 北控            2.8  93.6            112.7            109.6        3.1
# 山西            2.4  91.4            115.2            112.6        2.7
# 北京            1.3  88.5            110.0            108.4        1.5
# 福建            0.5  95.0            119.6            119.1        0.5
# ...

# %% [markdown]
# # 换帅后数据
# ### 假如我们只截取换帅后的数据（换帅后辽宁共打了13场比赛），辽宁的净效率排到联盟第二。

# %%
teams = Team('',after_change)

teams_after_change = pd.concat([teams.mov, teams.tm_pace, teams.tm_ortg, teams.tm_drtg, teams.tm_nrtg], axis=1)
teams_after_change.columns=['场均净胜分MOV', 'Pace', 'OffensiveRating', 'DefensiveRating', 'NetRating']
teams_after_change = teams_after_change.sort_values(by='NetRating',ascending=False)
teams_after_change.rename(index={'辽宁':"辽宁（换帅后）"},inplace=True)
print('换帅后辽宁共打了'+str(teams.tm_ngames['辽宁'])+"场比赛")
teams_after_change.round(1)
# Out:
# 换帅后辽宁共打了13.0场比赛
#          场均净胜分MOV   Pace  OffensiveRating  DefensiveRating  NetRating
# 球队
# 广东           22.0  100.2            122.7            100.2       22.5
# 辽宁（换帅后）      20.3   96.5            126.6            105.1       21.5
# 北京           15.7   88.5            111.6             93.5       18.1
# 新疆           16.5   94.1            112.8             94.9       17.9
# 浙江            9.4   92.2            115.8            105.4       10.4
# 广厦            4.8   95.8            112.8            107.7        5.1
# 福建           -0.6  100.1            113.2            113.7       -0.6
# 上海           -1.0   92.2            108.8            109.9       -1.1
# 八一           -3.7   92.0            105.0            109.0       -4.0
# 同曦           -4.2   97.9            110.3            114.6       -4.3
# 北控           -4.5   93.5            106.6            111.5       -4.9
# 深圳           -4.8   93.7            100.6            105.8       -5.2
# ...

# %% [markdown]
# # 整合数据
# ### 假如我们将换帅后的辽宁，换帅前的辽宁，与全联盟整赛季的球队高阶数据进行对比（包括辽宁队本身的整赛季数据），可以看到辽宁换帅后的净效率高居全联盟第一。当然，也跟换帅后的赛程有关（换帅后并未与目前联盟积分前四的广东，新疆，北京交手）。

# %%
merged_df = pd.concat([teams_whole_season.round(1),
                       pd.DataFrame(teams_before_change.loc['辽宁（换帅前）',:].round(1)).transpose(),
                       pd.DataFrame(teams_after_change.loc['辽宁（换帅后）',:].round(1)).transpose()])
merged_df = merged_df.sort_values(by='NetRating',ascending=False)
merged_df
# Out:
#          场均净胜分MOV  Pace  OffensiveRating  DefensiveRating  NetRating
# 辽宁（换帅后）      20.3  96.5            126.6            105.1       21.5
# 广东           20.3  98.3            125.9            104.8       21.2
# 新疆           11.3  94.8            118.4            106.3       12.1
# 辽宁（整赛季）       8.4  94.7            120.0            111.0        9.0
# 浙江            6.6  92.3            120.3            113.0        7.3
# 北京            5.3  88.5            110.4            104.3        6.1
# 广厦            5.5  95.2            113.5            107.6        5.9
# 辽宁（换帅前）       3.8  94.0            117.4            113.3        4.1
# 青岛            1.5  94.8            114.7            113.0        1.7
# 山东            1.2  92.0            113.1            111.8        1.3
# 吉林            1.0  92.2            115.8            114.7        1.1
# 北控            0.7  93.6            110.9            110.2        0.7
# 福建            0.2  96.5            117.7            117.5        0.2
# ...

# %% [markdown]
# # 辽宁本队球员数据对比

# %% [markdown]
# # 整赛季

# %%
players = Player('',whole_season)

# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
players_df = pd.concat([players.plr_ortg, players.plr_drtg, players.plr_nrtg,players.plr_usg,players.plr_mp], axis=1)
players_df.columns=['OffensiveRating', 'DefensiveRating', 'NetRating','UsagePercent','MinutesPlayed']
players_df = players_df.sort_values(by=['NetRating','UsagePercent'],ascending=False)

# %%
raw_stats =  players.all_games_stats
player_list = raw_stats.loc[(raw_stats['球队']=='辽宁'),].球员.value_counts().index.to_list()
rename_dict = {player:player+'（整赛季）' for player in player_list}

# %% [markdown]
# ### 整赛季高阶数据

# %%
whole_season_advance = players_df.loc[player_list].rename(index=rename_dict)

# %% [markdown]
# ### 整赛季场均数据

# %%
raw_stats =  players.all_games_stats
print(raw_stats.loc[(raw_stats['球队']=='辽宁'),].groupby('球员').sum()['出场'])
avg_stats = raw_stats.loc[(raw_stats['球队']=='辽宁')&(raw_stats['出场']==1),].groupby('球员').mean().round(2)
whole_season_avg = avg_stats.rename(index=rename_dict)
# Out:
# 球员
# 丛明晨     17
# 刘志轩     35
# 刘雁宇     15
# 卢梓杰      0
# 史蒂芬森    29
# 孙锴祺      0
# 巴斯      30
# 李晓旭     37
# 梅奥      16
# 王化东     25
# 贺天举     43
# 赵继伟     46
# 郭旭      33
# 郭艾伦     36
# 鄢手骐      6
# 韩德君     45
# 马壮       3
# 高诗岩     47
# Name: 出场, dtype: int64

# %% [markdown]
# # 换帅前

# %%
players = Player('',before_change)

# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
players_df = pd.concat([players.plr_ortg, players.plr_drtg, players.plr_nrtg,players.plr_usg,players.plr_mp], axis=1)
players_df.columns=['OffensiveRating', 'DefensiveRating', 'NetRating','UsagePercent','MinutesPlayed']
players_df = players_df.sort_values(by=['NetRating','UsagePercent'],ascending=False)

# %%
raw_stats =  players.all_games_stats
player_list = raw_stats.loc[(raw_stats['球队']=='辽宁'),].球员.value_counts().index.to_list()
rename_dict = {player:player+'（换帅前）' for player in player_list}

# %% [markdown]
# ### 换帅前高阶数据

# %%
before_change_advance = players_df.loc[player_list].rename(index=rename_dict)

# %% [markdown]
# ### 换帅前场均数据

# %%
raw_stats =  players.all_games_stats
print(raw_stats.loc[(raw_stats['球队']=='辽宁'),].groupby('球员').sum()['出场'])
raw_stats.loc[(raw_stats['球队']=='辽宁'),].groupby('球员').sum()['出场']
avg_stats = raw_stats.loc[(raw_stats['球队']=='辽宁')&(raw_stats['出场']==1),].groupby('球员').mean().round(2)
before_change_avg = avg_stats.rename(index=rename_dict)
# Out:
# 球员
# 丛明晨      5
# 刘志轩     24
# 刘雁宇      3
# 卢梓杰      0
# 史蒂芬森    29
# 孙锴祺      0
# 巴斯      30
# 李晓旭     30
# 梅奥       3
# 王化东     13
# 贺天举     31
# 赵继伟     33
# 郭旭      24
# 郭艾伦     25
# 鄢手骐      2
# 韩德君     32
# 马壮       3
# 高诗岩     34
# Name: 出场, dtype: int64

# %% [markdown]
# # 换帅后

# %%
players = Player('',after_change)

# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
players_df = pd.concat([players.plr_ortg, players.plr_drtg, players.plr_nrtg,players.plr_usg,players.plr_mp], axis=1)
players_df.columns=['OffensiveRating', 'DefensiveRating', 'NetRating','UsagePercent','MinutesPlayed']
players_df = players_df.sort_values(by=['NetRating','UsagePercent'],ascending=False)

# %%
raw_stats =  players.all_games_stats
player_list = raw_stats.loc[(raw_stats['球队']=='辽宁'),].球员.value_counts().index.to_list()
rename_dict = {player:player+'（换帅后）' for player in player_list}

# %% [markdown]
# ### 换帅后高阶数据

# %%
after_change_advance = players_df.loc[player_list].rename(index=rename_dict)

# %% [markdown]
# ### 换帅后场均数据

# %%
raw_stats =  players.all_games_stats
print(raw_stats.loc[(raw_stats['球队']=='辽宁'),].groupby('球员').sum()['出场'])
raw_stats.loc[(raw_stats['球队']=='辽宁'),].groupby('球员').sum()['出场']
avg_stats = raw_stats.loc[(raw_stats['球队']=='辽宁')&(raw_stats['出场']==1),].groupby('球员').mean().round(2)
after_change_avg = avg_stats.rename(index=rename_dict)
# Out:
# 球员
# 丛明晨    12
# 刘志轩    11
# 刘雁宇    12
# 卢梓杰     0
# 孙锴祺     0
# 李晓旭     7
# 梅奥     13
# 王化东    12
# 贺天举    12
# 赵继伟    13
# 郭旭      9
# 郭艾伦    11
# 鄢手骐     4
# 韩德君    13
# 马壮      0
# 高诗岩    13
# Name: 出场, dtype: int64

# %%
merged_advance = pd.concat([whole_season_advance,before_change_advance,after_change_advance])
merged_advance.sort_values(by='球员')
# Out:
#            OffensiveRating  DefensiveRating  NetRating  UsagePercent  \
# 球员
# 丛明晨（换帅前）         97.402907       120.749321 -23.346414      9.396699
# 丛明晨（换帅后）        122.737198       110.378321  12.358876     14.581692
# 丛明晨（整赛季）        117.411087       116.819786   0.591301     13.127890
# 刘志轩（换帅前）        111.983585       119.598414  -7.614830      7.678762
# 刘志轩（换帅后）         97.963977       113.780661 -15.816684      8.413876
# 刘志轩（整赛季）        106.845293       118.060198 -11.214905      7.914845
# 刘雁宇（换帅前）         86.260435       117.055579 -30.795145     14.250918
# 刘雁宇（换帅后）        104.982748       110.081059  -5.098312     17.745396
# 刘雁宇（整赛季）        102.036941       115.852912 -13.815971     17.441625
# 卢梓杰（换帅前）               NaN              NaN        NaN           NaN
# 卢梓杰（换帅后）               NaN              NaN        NaN           NaN
# 卢梓杰（整赛季）               NaN              NaN        NaN           NaN
# ...

# %%
merged_avg = pd.concat([whole_season_avg,before_change_avg,after_change_avg])
merged_avg.sort_values(by='球员')
# Out:
#             出场时间    首发  进攻篮板  防守篮板    助攻    犯规    抢断    失误    盖帽    扣篮    被侵  \
# 球员
# 丛明晨（换帅前）   16.00  0.20  0.40  1.60  0.40  1.00  0.40  0.20  0.00  0.00  0.20
# 丛明晨（换帅后）   15.50  0.33  0.33  1.33  0.42  1.42  0.67  0.58  0.08  0.00  0.42
# 丛明晨（整赛季）   15.65  0.29  0.35  1.41  0.41  1.29  0.59  0.47  0.06  0.00  0.35
# 刘志轩（换帅前）   22.00  0.04  0.58  1.38  2.25  1.46  0.75  0.58  0.04  0.00  0.58
# 刘志轩（换帅后）   21.73  0.45  0.55  1.00  2.82  1.91  0.27  0.91  0.09  0.00  0.45
# 刘志轩（整赛季）   21.91  0.17  0.57  1.26  2.43  1.60  0.60  0.69  0.06  0.00  0.54
# 刘雁宇（换帅前）    6.00  0.00  0.67  1.67  0.00  1.00  0.00  0.67  0.67  0.00  0.67
# 刘雁宇（换帅后）    9.58  0.00  0.58  1.67  0.08  2.00  0.17  0.83  0.50  0.42  1.25
# 刘雁宇（整赛季）    8.87  0.00  0.60  1.67  0.07  1.80  0.13  0.80  0.53  0.33  1.13
# 史蒂芬森（换帅前）  34.79  0.93  1.07  6.38  3.83  3.31  1.07  2.90  0.17  0.55  6.34
# 史蒂芬森（整赛季）  34.79  0.93  1.07  6.38  3.83  3.31  1.07  2.90  0.17  0.55  6.34
# ...
