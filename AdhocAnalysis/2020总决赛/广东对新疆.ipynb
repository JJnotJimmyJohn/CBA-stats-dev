# %%
import pandas as pd
import bokeh

# %%
df = pd.read_csv('StatsData/All_Games_Stats_2020-01-18.csv')
df.head()
# Out:
#      球员  号码  出场时间  首发  进攻篮板  防守篮板  助攻  犯规  抢断  失误  ...  得分        Game_ID  球队  \
# 0  布鲁克斯   6    36   1     0     3   9   3   2   1  ...  27  2019202000001  广东
# 1   任骏飞  20    30   1     1     1   1   3   3   0  ...  19  2019202000001  广东
# 2   易建联   9    35   1     1    11   2   2   1   1  ...  16  2019202000001  广东
# 3    赵睿  10    31   1     2     5   4   3   2   0  ...  10  2019202000001  广东
# 4   胡明轩   3    13   1     0     1   0   1   0   1  ...   3  2019202000001  广东
#
#    对手  2分中  2分投 3分中 3分投  罚球中  罚球投
# 0  辽宁    8   10   2  10    5    5
# 1  辽宁    5    8   3   6    0    0
# 2  辽宁    7    8   0   0    2    4
# 3  辽宁    5    9   0   3    0    1
# 4  辽宁    0    1   1   3    0    0
#
# [5 rows x 24 columns]

# %%
df.query("球队=='新疆' and 对手=='辽宁'").sum()
# Out:
# 球员         凯-费尔德周琦阿不都沙拉木可兰白克俞长栋范子铭唐才育西热力江曾令旭刘力鹏鲁吐布拉刘羽楠热甫卡...
# 号码                                                       227
# 出场时间                                                     235
# 首发                                                         5
# 进攻篮板                                                      16
# 防守篮板                                                      26
# 助攻                                                        26
# 犯规                                                        27
# 抢断                                                        16
# 失误                                                        13
# 盖帽                                                         1
# 扣篮                                                         1
# 被侵                                                        24
# 快攻          0/00/00/00/00/00/00/00/00/00/00/00/00/00/00/00/0
# 得分                                                       127
# ...
